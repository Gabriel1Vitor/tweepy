# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriel1Vitor/tweepy/blob/main/Tweepy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import pylab as pl
from bs4 import BeautifulSoup
import tweepy

# %% [markdown]
# Senhas entragas pelo twitter apos o projeto registrado na plataforma

# %%
consumer_key='MtNKgCMJ9WeMiYIjNMkTxBN70'
consumer_secret='4dBzAbxSyaa82QaILOM3qadtlm58Q2okUw9oA4ARFA72CASRyG'
access_token='1464931722546630662-J3WkVa5hrCItCjzzbmXuTwsRPRvVPv'
access_token_secret='mjxvk0mDwu7Fjs8W58qZAiov8Qi2hMeUntG9K22hif7h9'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %% [markdown]
# Os textos da API são em json

# %%
api = tweepy.API(auth)
seach='#Eleicoes2022'+'-filter:retweets'#Hashtag

tweets=tweepy.Cursor(api.search,q=seach).items(1)

for tweet in tweets:
    (tweet.text)
    print(tweet)
# Out:
# Status(_api=<tweepy.api.API object at 0x7fd2566b2cd0>, _json={'created_at': 'Thu Jan 19 12:07:18 +0000 2023', 'id': 1616044628557369351, 'id_str': '1616044628557369351', 'text': 'Faz o L \n#Eleicoes2022 \n#vida #Brasil \n#politica #educação \n#ensino https://t.co/oMm4SV6Bos', 'truncated': False, 'entities': {'hashtags': [{'text': 'Eleicoes2022', 'indices': [9, 22]}, {'text': 'vida', 'indices': [24, 29]}, {'text': 'Brasil', 'indices': [30, 37]}, {'text': 'politica', 'indices': [39, 48]}, {'text': 'educação', 'indices': [49, 58]}, {'text': 'ensino', 'indices': [60, 67]}], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1616044619090857984, 'id_str': '1616044619090857984', 'indices': [68, 91], 'media_url': 'http://pbs.twimg.com/media/Fm1YBNYXkAAliEQ.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Fm1YBNYXkAAliEQ.jpg', 'url': 'https://t.co/oMm4SV6Bos', 'display_url': 'pic.twitter.com/oMm4SV6Bos', 'expanded_url': 'https://twitter.com/marcosperfil2/status/16160446285
# ...

# %% [markdown]
# Uma das varias formas de tranformar json em Pandas(DataFrame)

# %%
t=tweet._json.keys()
tweets_dict={}
tweets_dict=tweets_dict.fromkeys(t)
seach='#Eleicoes2022'+'-filter:retweets'
cursortweets=tweepy.Cursor(api.search,q=seach).items(2000)

for tweet in cursortweets:
    for key in tweets_dict.keys():
       try:
           t=tweet._json[key]
           tweets_dict[key].append(t)
       except KeyError:
           t = ""
           tweets_dict[key].append("")
       except:
           tweets_dict[key] = [t]


data=pd.DataFrame.from_dict(tweets_dict)
data.tail()
# Out:
#                          created_at                   id               id_str  \
# 97   Sun Jan 15 13:58:01 +0000 2023  1614622936781955073  1614622936781955073
# 98   Sun Jan 15 13:34:51 +0000 2023  1614617106665947142  1614617106665947142
# 99   Sun Jan 15 12:40:19 +0000 2023  1614603384736079877  1614603384736079877
# 100  Sun Jan 15 12:28:44 +0000 2023  1614600469892005888  1614600469892005888
# 101  Sun Jan 15 11:18:41 +0000 2023  1614582839466692609  1614582839466692609
#
#                                                   text  truncated  \
# 97   É preciso. É urgente. Só 5 dias.\n#grevedoscam...       True
# 98   Quando será aberto uma CPI pra apurar eventuai...       True
# 99   📚 Essa gente é completamente fanática e maluca...       True
# 100  Esperando alguém mandar a planilha de gastos d...       True
# 101  @IvanValente Na prática, Bolsonaro já está pre...       True
#
#                                               entities extended_entities  \
# ...
